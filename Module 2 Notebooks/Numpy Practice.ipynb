# %%
import numpy as np

# %%
a = np.array([1,2,3,4,5])
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
b = np.arange(2, 3)
# OR
b = np.array([[1,2,3], [4,5,6]])
b.shape
# Out:
# (2, 3)

# %%
type(a)
# Out:
# numpy.ndarray

# %%
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((2,2))
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
np.empty((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.linspace(0, 10, num=4, dtype=np.int64)
# Out:
# array([ 0,  3,  6, 10], dtype=int64)

# %%
array1 = np.array([10, 33,43, 63, 23 ,34, 21, 53, 23, 1])
np.sort(array1)
# Out:
# array([ 1, 10, 21, 23, 23, 33, 34, 43, 53, 63])

# %%
np.argsort(array1, kind='quicksort', axis=None) #argsort specified axis/ OR sort indexes
# Out:
# array([9, 0, 6, 4, 8, 1, 5, 2, 7, 3], dtype=int64)

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('QVI_fulldata.csv')
df
# Out:
#         Unnamed: 0  LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0                0            1000  2018-10-17          1       1         5
# 1                1            1002  2018-09-16          1       2        58
# 2                2            1003  2019-03-07          1       3        52
# 3                3            1003  2019-03-08          1       4       106
# 4                4            1004  2018-11-02          1       5        96
# ...            ...             ...         ...        ...     ...       ...
# 246735      246735         2370651  2018-08-03         88  240350         4
# 246736      246736         2370701  2018-12-08         88  240378        24
# 246737      246737         2370751  2018-10-01         88  240394        60
# 246738      246738         2370961  2018-10-24         88  240480        70
# 246739      246739         2373711  2018-12-14         88  241815        16
#
# ...

# %%
df.shape
# Out:
# (246740, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246740 entries, 0 to 246739
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      246740 non-null  int64
#  1   LYLTY_CARD_NBR  246740 non-null  int64
#  2   DATE            246740 non-null  object
#  3   STORE_NBR       246740 non-null  int64
#  4   TXN_ID          246740 non-null  int64
#  5   PROD_NBR        246740 non-null  int64
#  6   PROD_NAME       246740 non-null  object
#  7   PROD_QTY        246740 non-null  int64
#  8   TOT_SALES       246740 non-null  float64
#  9   PACK_SIZE       246740 non-null  float64
#  10  BRAND_NAME      246740 non-null  object
#  11  LIFESTAGE       246740 non-null  object
#  12  MEMBER_TYPE     246740 non-null  object
# dtypes: float64(2), int64(6), object(5)
# memory usage: 24.5+ MB

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    Unnamed: 0  LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0           0            1000  2018-10-17          1       1         5
# 1           1            1002  2018-09-16          1       2        58
# 2           2            1003  2019-03-07          1       3        52
# 3           3            1003  2019-03-08          1       4       106
# 4           4            1004  2018-11-02          1       5        96
#
#                                 PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE  \
# 0  Natural Chip        Compny SeaSalt175g         2        6.0      175.0
# 1   Red Rock Deli Chikn&Garlic Aioli 150g         1        2.7      150.0
# 2   Grain Waves Sour    Cream&Chives 210G         1        3.6      210.0
# 3  Natural ChipCo      Hony Soy Chckn175g         1        3.0      175.0
# 4          WW Original Stacked Chips 160g         1        1.9      160.0
#
#         BRAND_NAME              LIFESTAGE MEMBER_TYPE
# ...

# %%
df.tail(1)
# Out:
#         Unnamed: 0  LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 246739      246739         2373711  2018-12-14         88  241815        16
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES  \
# 246739  Smiths Crinkle Chips Salt & Vinegar 330g         2       11.4
#
#         PACK_SIZE BRAND_NAME              LIFESTAGE MEMBER_TYPE
# 246739      330.0     Smiths  YOUNG SINGLES/COUPLES  Mainstream

# %%
df.describe()
# Out:
#           Unnamed: 0  LYLTY_CARD_NBR      STORE_NBR        TXN_ID  \
# count  246740.000000    2.467400e+05  246740.000000  2.467400e+05
# mean   123369.500000    1.355303e+05     135.050361  1.351304e+05
# std     71227.847047    8.071520e+04      76.786971  7.814760e+04
# min         0.000000    1.000000e+03       1.000000  1.000000e+00
# 25%     61684.750000    7.001500e+04      70.000000  6.756875e+04
# 50%    123369.500000    1.303670e+05     130.000000  1.351815e+05
# 75%    185054.250000    2.030832e+05     203.000000  2.026522e+05
# max    246739.000000    2.373711e+06     272.000000  2.415841e+06
#
#             PROD_NBR       PROD_QTY      TOT_SALES      PACK_SIZE
# count  246740.000000  246740.000000  246740.000000  246740.000000
# mean       56.352213       1.906456       7.316113     175.583521
# std        33.695235       0.342499       2.474897      59.432118
# min         1.000000       1.000000       1.700000      70.000000
# ...

# %% [markdown]
# **Above part shows some main things:**
# **- 272 Stores**
# **- 114 Products**
# **- Quality Max 5**
# **- Max Sale 29**

# %%
df['PROD_NAME']
# Out:
# 0           Natural Chip        Compny SeaSalt175g
# 1            Red Rock Deli Chikn&Garlic Aioli 150g
# 2            Grain Waves Sour    Cream&Chives 210G
# 3           Natural ChipCo      Hony Soy Chckn175g
# 4                   WW Original Stacked Chips 160g
#                             ...
# 246735            Dorito Corn Chp     Supreme 380g
# 246736       Grain Waves         Sweet Chilli 210g
# 246737        Kettle Tortilla ChpsFeta&Garlic 150g
# 246738     Tyrrells Crisps     Lightly Salted 165g
# 246739    Smiths Crinkle Chips Salt & Vinegar 330g
# Name: PROD_NAME, Length: 246740, dtype: object

# %%
df[['STORE_NBR', 'PROD_NAME', 'BRAND_NAME', 'LIFESTAGE', 'TOT_SALES']]
# Out:
#         STORE_NBR                                 PROD_NAME       BRAND_NAME  \
# 0               1    Natural Chip        Compny SeaSalt175g  Natural Chip Co
# 1               1     Red Rock Deli Chikn&Garlic Aioli 150g    Red Rock Deli
# 2               1     Grain Waves Sour    Cream&Chives 210G      Grain Waves
# 3               1    Natural ChipCo      Hony Soy Chckn175g  Natural Chip Co
# 4               1            WW Original Stacked Chips 160g       Woolworths
# ...           ...                                       ...              ...
# 246735         88          Dorito Corn Chp     Supreme 380g          Doritos
# 246736         88     Grain Waves         Sweet Chilli 210g      Grain Waves
# 246737         88      Kettle Tortilla ChpsFeta&Garlic 150g           Kettle
# 246738         88   Tyrrells Crisps     Lightly Salted 165g         Tyrrells
# 246739         88  Smiths Crinkle Chips Salt & Vinegar 330g           Smiths
#
#                      LIFESTAGE  TOT_SALES
# ...

# %%
df.iloc[0]
# Out:
# Unnamed: 0                                             0
# LYLTY_CARD_NBR                                      1000
# DATE                                          2018-10-17
# STORE_NBR                                              1
# TXN_ID                                                 1
# PROD_NBR                                               5
# PROD_NAME         Natural Chip        Compny SeaSalt175g
# PROD_QTY                                               2
# TOT_SALES                                            6.0
# PACK_SIZE                                          175.0
# BRAND_NAME                               Natural Chip Co
# LIFESTAGE                          YOUNG SINGLES/COUPLES
# MEMBER_TYPE                                      Premium
# Name: 0, dtype: object

# %%
df.iloc[1:5]
# Out:
#    Unnamed: 0  LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 1           1            1002  2018-09-16          1       2        58
# 2           2            1003  2019-03-07          1       3        52
# 3           3            1003  2019-03-08          1       4       106
# 4           4            1004  2018-11-02          1       5        96
#
#                                 PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE  \
# 1   Red Rock Deli Chikn&Garlic Aioli 150g         1        2.7      150.0
# 2   Grain Waves Sour    Cream&Chives 210G         1        3.6      210.0
# 3  Natural ChipCo      Hony Soy Chckn175g         1        3.0      175.0
# 4          WW Original Stacked Chips 160g         1        1.9      160.0
#
#         BRAND_NAME              LIFESTAGE MEMBER_TYPE
# 1    Red Rock Deli  YOUNG SINGLES/COUPLES  Mainstream
# 2      Grain Waves         YOUNG FAMILIES      Budget
# 3  Natural Chip Co         YOUNG FAMILIES      Budget
# ...

# %%
df.iloc[1:10:2]
# Out:
#    Unnamed: 0  LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 1           1            1002  2018-09-16          1       2        58
# 3           3            1003  2019-03-08          1       4       106
# 5           5            1005  2018-12-28          1       6        86
# 7           7            1007  2018-12-05          1       8        10
# 9           9            1010  2018-09-09          1      10        51
#
#                                 PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE  \
# 1   Red Rock Deli Chikn&Garlic Aioli 150g         1        2.7      150.0
# 3  Natural ChipCo      Hony Soy Chckn175g         1        3.0      175.0
# 5                      Cheetos Puffs 165g         1        2.8      165.0
# 7     RRD SR Slow Rst     Pork Belly 150g         1        2.7      150.0
# 9                Doritos Mexicana    170g         2        8.8      170.0
#
#         BRAND_NAME               LIFESTAGE MEMBER_TYPE
# ...

# %%
df.iloc[[1,2,3]]
# Out:
#    Unnamed: 0  LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 1           1            1002  2018-09-16          1       2        58
# 2           2            1003  2019-03-07          1       3        52
# 3           3            1003  2019-03-08          1       4       106
#
#                                 PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE  \
# 1   Red Rock Deli Chikn&Garlic Aioli 150g         1        2.7      150.0
# 2   Grain Waves Sour    Cream&Chives 210G         1        3.6      210.0
# 3  Natural ChipCo      Hony Soy Chckn175g         1        3.0      175.0
#
#         BRAND_NAME              LIFESTAGE MEMBER_TYPE
# 1    Red Rock Deli  YOUNG SINGLES/COUPLES  Mainstream
# 2      Grain Waves         YOUNG FAMILIES      Budget
# 3  Natural Chip Co         YOUNG FAMILIES      Budget

# %%
df.iloc[:, [3,5,6,10,11,8]]
# Out:
#         STORE_NBR  PROD_NBR                                 PROD_NAME  \
# 0               1         5    Natural Chip        Compny SeaSalt175g
# 1               1        58     Red Rock Deli Chikn&Garlic Aioli 150g
# 2               1        52     Grain Waves Sour    Cream&Chives 210G
# 3               1       106    Natural ChipCo      Hony Soy Chckn175g
# 4               1        96            WW Original Stacked Chips 160g
# ...           ...       ...                                       ...
# 246735         88         4          Dorito Corn Chp     Supreme 380g
# 246736         88        24     Grain Waves         Sweet Chilli 210g
# 246737         88        60      Kettle Tortilla ChpsFeta&Garlic 150g
# 246738         88        70   Tyrrells Crisps     Lightly Salted 165g
# 246739         88        16  Smiths Crinkle Chips Salt & Vinegar 330g
#
#              BRAND_NAME               LIFESTAGE  TOT_SALES
# 0       Natural Chip Co   YOUNG SINGLES/COUPLES        6.0
# ...

# %% [markdown]
# # Masking

# %%
mask = df['PROD_QTY'] == 5
mask
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 246735    False
# 246736    False
# 246737    False
# 246738    False
# 246739    False
# Name: PROD_QTY, Length: 246740, dtype: bool

# %%
maskdf = df[mask]
mask2 = maskdf['PROD_NBR'] == 58
maskdf[mask2]
# Out:
#         Unnamed: 0  LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 66122        66122           73133  2018-08-16         73   72421        58
# 70026        70026           78216  2018-08-17         78   76717        58
# 133582      133582          147114  2018-08-15        147  146392        58
# 147371      147371          160208  2019-05-19        160  161450        58
# 210779      210779          229083  2019-05-17        229  230865        58
# 233217      233217          256255  2019-05-16        256  255411        58
# 234642      234642          257202  2018-08-20        257  256977        58
#
#                                     PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE  \
# 66122   Red Rock Deli Chikn&Garlic Aioli 150g         5       13.5      150.0
# 70026   Red Rock Deli Chikn&Garlic Aioli 150g         5       13.5      150.0
# 133582  Red Rock Deli Chikn&Garlic Aioli 150g         5       13.5      150.0
# ...

# %%
mask4 = df['TOT_SALES'] > df['TOT_SALES'].mean()
mask3 = df['PROD_QTY'] == 5

df[mask4 & mask3].shape[0]
# Out:
# 413

# %%
df['PROD_NAME'].value_counts()
# Out:
# PROD_NAME
# Kettle Mozzarella   Basil & Pesto 175g      3304
# Kettle Tortilla ChpsHny&Jlpno Chili 150g    3296
# Cobs Popd Swt/Chlli &Sr/Cream Chips 110g    3269
# Tyrrells Crisps     Ched & Chives 165g      3268
# Cobs Popd Sea Salt  Chips 110g              3265
#                                             ...
# Sunbites Whlegrn    Crisps Frch/Onin 90g    1432
# RRD Pc Sea Salt     165g                    1431
# NCC Sour Cream &    Garden Chives 175g      1419
# French Fries Potato Chips 175g              1418
# WW Crinkle Cut      Original 175g           1410
# Name: count, Length: 105, dtype: int64

# %%
df['LIFESTAGE'].value_counts()
# Out:
# LIFESTAGE
# OLDER SINGLES/COUPLES     50793
# RETIREES                  46431
# OLDER FAMILIES            45158
# YOUNG FAMILIES            40494
# YOUNG SINGLES/COUPLES     33969
# MIDAGE SINGLES/COUPLES    23398
# NEW FAMILIES               6497
# Name: count, dtype: int64

# %%
mask5 = df['LIFESTAGE'] == 'OLDER SINGLES/COUPLES'
maskdf = df[mask5]
maskdf['PROD_NAME']
# Out:
# 4                   WW Original Stacked Chips 160g
# 10           GrnWves Plus Btroot & Chilli Jam 180g
# 11        Infuzions SourCream&Herbs Veg Strws 110g
# 12         Smiths Crinkle Cut  Chips Barbecue 170g
# 22           GrnWves Plus Btroot & Chilli Jam 180g
#                             ...
# 246729                Kettle 135g Swt Pot Sea Salt
# 246730      Kettle Mozzarella   Basil & Pesto 175g
# 246732              Pringles SourCream  Onion 134g
# 246733     Doritos Corn Chip Southern Chicken 150g
# 246734     Kettle Tortilla ChpsBtroot&Ricotta 150g
# Name: PROD_NAME, Length: 50793, dtype: object

# %% [markdown]
# # Plotting

# %%
import matplotlib as plt

# %%
df['LIFESTAGE'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='LIFESTAGE'>

# %%
df['LIFESTAGE'].value_counts().head().plot(kind='bar')
# Out:
# <Axes: xlabel='LIFESTAGE'>

# %%
df['MEMBER_TYPE'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['TOT_SALES'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Series

# %%
df['LIFESTAGE'].value_counts()
# Out:
# LIFESTAGE
# OLDER SINGLES/COUPLES     50793
# RETIREES                  46431
# OLDER FAMILIES            45158
# YOUNG FAMILIES            40494
# YOUNG SINGLES/COUPLES     33969
# MIDAGE SINGLES/COUPLES    23398
# NEW FAMILIES               6497
# Name: count, dtype: int64

# %%
type(df['LIFESTAGE'].value_counts())
# Out:
# pandas.core.series.Series

# %%
df['LIFESTAGE'].value_counts().values
# Out:
# array([50793, 46431, 45158, 40494, 33969, 23398,  6497], dtype=int64)

# %%
df['LIFESTAGE'].value_counts().index
# Out:
# Index(['OLDER SINGLES/COUPLES', 'RETIREES', 'OLDER FAMILIES', 'YOUNG FAMILIES',
#        'YOUNG SINGLES/COUPLES', 'MIDAGE SINGLES/COUPLES', 'NEW FAMILIES'],
#       dtype='object', name='LIFESTAGE')

# %%
myseries = df['LIFESTAGE'].value_counts()
myseries['OLDER FAMILIES']
# Out:
# 45158

# %%
df.head()
# Out:
#    Unnamed: 0  LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0           0            1000  2018-10-17          1       1         5
# 1           1            1002  2018-09-16          1       2        58
# 2           2            1003  2019-03-07          1       3        52
# 3           3            1003  2019-03-08          1       4       106
# 4           4            1004  2018-11-02          1       5        96
#
#                                 PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE  \
# 0  Natural Chip        Compny SeaSalt175g         2        6.0      175.0
# 1   Red Rock Deli Chikn&Garlic Aioli 150g         1        2.7      150.0
# 2   Grain Waves Sour    Cream&Chives 210G         1        3.6      210.0
# 3  Natural ChipCo      Hony Soy Chckn175g         1        3.0      175.0
# 4          WW Original Stacked Chips 160g         1        1.9      160.0
#
#         BRAND_NAME              LIFESTAGE MEMBER_TYPE
# ...

# %% [markdown]
# we can add 2 series using "+" operator. when its indexes are same

# %% [markdown]
# # Sort_Values

# %%
myseries.sort_values(ascending=False)
# Out:
# LIFESTAGE
# OLDER SINGLES/COUPLES     50793
# RETIREES                  46431
# OLDER FAMILIES            45158
# YOUNG FAMILIES            40494
# YOUNG SINGLES/COUPLES     33969
# MIDAGE SINGLES/COUPLES    23398
# NEW FAMILIES               6497
# Name: count, dtype: int64

# %%
#for datafrome
df.sort_values('PROD_NAME')
# Out:
#         Unnamed: 0  LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 173294      173294          189008  2019-02-17        189  189891        94
# 158880      158880          172212  2019-05-16        172  174077        94
# 219090      219090          236244  2019-05-29        236  240036        94
# 219107      219107          236247  2018-08-29        236  240053        94
# 39566        39566           48052  2019-06-28         48   43362        94
# ...            ...             ...         ...        ...     ...       ...
# 18488        18488           24001  2019-05-31         24   20263       105
# 138255      138255          152187  2018-08-23        152  151473       105
# 85177        85177           94125  2019-02-03         94   93246       105
# 53635        53635           62156  2018-10-20         62   58720       105
# 38250        38250           46094  2018-09-09         46   41909       105
#
# ...

# %% [markdown]
# # drop_duplicates()

# %%
dup = df.duplicated().sum()
dup
# df[dup]
# Out:
# 0

# %%
df.drop_duplicates(keep='last')
# Out:
#         Unnamed: 0  LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0                0            1000  2018-10-17          1       1         5
# 1                1            1002  2018-09-16          1       2        58
# 2                2            1003  2019-03-07          1       3        52
# 3                3            1003  2019-03-08          1       4       106
# 4                4            1004  2018-11-02          1       5        96
# ...            ...             ...         ...        ...     ...       ...
# 246735      246735         2370651  2018-08-03         88  240350         4
# 246736      246736         2370701  2018-12-08         88  240378        24
# 246737      246737         2370751  2018-10-01         88  240394        60
# 246738      246738         2370961  2018-10-24         88  240480        70
# 246739      246739         2373711  2018-12-14         88  241815        16
#
# ...

# %% [markdown]
# # Groupby

# %%
groups = df.groupby('BRAND_NAME')

# %%
len(groups)
# Out:
# 20

# %%
groups.size().sort_values()
# Out:
# BRAND_NAME
# French              1418
# Burger              1564
# Cheetos             2927
# Sunbites            3008
# CCs                 4551
# Cheezels            4603
# Tyrrells            6442
# Natural Chip Co     7469
# Grain Waves         7740
# Twisties            9454
# Tostitos            9471
# Cobs                9693
# Woolworths         11836
# Thins              14075
# Infuzions          14201
# Red Rock Deli      16321
# Pringles           25102
# Doritos            25224
# Smiths             30353
# Kettle             41288
# dtype: int64

# %%
groups.first()
# Out:
#                  Unnamed: 0  LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  \
# BRAND_NAME
# Burger                   38            1042  2018-07-21          1      45
# CCs                      16            1013  2019-03-07          1      19
# Cheetos                   5            1005  2018-12-28          1       6
# Cheezels                 57            1057  2018-07-06          1      64
# Cobs                     34            1034  2019-03-24          1      38
# Doritos                   8            1009  2018-11-20          1       9
# French                   97            1097  2018-11-27          1     111
# Grain Waves               2            1003  2019-03-07          1       3
# Infuzions                 6            1007  2018-12-04          1       7
# Kettle                   14            1012  2019-06-19          1      17
# Natural Chip Co           0            1000  2018-10-17          1       1
# ...

# %%
groups.count()
# Out:
#                  Unnamed: 0  LYLTY_CARD_NBR   DATE  STORE_NBR  TXN_ID  \
# BRAND_NAME
# Burger                 1564            1564   1564       1564    1564
# CCs                    4551            4551   4551       4551    4551
# Cheetos                2927            2927   2927       2927    2927
# Cheezels               4603            4603   4603       4603    4603
# Cobs                   9693            9693   9693       9693    9693
# Doritos               25224           25224  25224      25224   25224
# French                 1418            1418   1418       1418    1418
# Grain Waves            7740            7740   7740       7740    7740
# Infuzions             14201           14201  14201      14201   14201
# Kettle                41288           41288  41288      41288   41288
# Natural Chip Co        7469            7469   7469       7469    7469
# Pringles              25102           25102  25102      25102   25102
# ...

# %%
groups.groups
# Out:
# {'Burger': [38, 275, 286, 334, 363, 402, 516, 519, 646, 679, 750, 752, 760, 764, 4074, 4182, 4496, 4658, 4801, 4960, 5057, 5096, 5238, 5320, 5409, 5522, 5562, 5647, 5709, 7802, 8012, 8067, 8088, 8131, 8151, 8266, 8363, 8367, 8413, 8465, 8582, 8584, 8707, 8800, 8918, 8958, 8987, 9047, 9114, 9233, 9523, 9540, 9556, 10217, 10309, 10363, 10370, 10405, 10625, 10726, 10742, 10765, 10946, 11074, 11126, 11152, 11230, 11237, 11274, 11287, 11336, 11446, 11497, 11587, 11614, 11699, 11770, 11857, 11931, 11957, 12213, 12216, 12237, 12268, 12508, 12648, 12780, 12785, 12876, 12921, 12944, 13228, 14004, 14041, 14165, 14273, 14293, 15583, 15590, 15713, ...], 'CCs': [16, 30, 90, 103, 109, 113, 136, 143, 144, 154, 169, 213, 290, 298, 308, 310, 354, 387, 388, 401, 520, 638, 639, 664, 708, 722, 799, 800, 801, 802, 875, 878, 889, 946, 4035, 4112, 4118, 4120, 4124, 4157, 4187, 4249, 4254, 4295, 4347, 4352, 4382, 4401, 4425, 4535, 4542, 4595, 4634, 4733, 4753, 4874, 4885, 4894, 4897, 4902, 4931, 4965, 5010,
# ...

# %%
groups.get_group('Burger')
# Out:
#         Unnamed: 0  LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 38              38            1042  2018-07-21          1      45        94
# 275            275            1277  2019-05-31          1     312        94
# 286            286            1286  2019-02-22          1     323        94
# 334            334            1335  2018-08-06          1     374        94
# 363            363            1357  2019-05-25          1     407        94
# ...            ...             ...         ...        ...     ...       ...
# 246031      246031          271213  2018-10-29        271  269486        94
# 246063      246063          271219  2018-09-28        271  269520        94
# 246109      246109          271228  2019-05-15        271  269572        94
# 246133      246133          271232  2018-10-06        271  269601        94
# 246718      246718         2330211  2018-07-17         77  236744        94
#
# ...

# %% [markdown]
# # Data Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips_data = sns.load_dataset('tips')

# %%
tips_data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import numpy as np
X = np.linspace(1,20, 100)
Y = np.exp(X)

plt.plot(X, Y)

plt.show()

# %%
plt.plot(X,Y, 'r*')

# %%
Y1 = X
Y2 = np.square(X)
Y3 = np.sqrt(X)

plt.plot(X, Y1, 'r', X, Y2, 'b', X, Y3, 'g')

plt.title('Line Plot')

plt.show()

# %%
tips_data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
X = tips_data['total_bill']
Y = tips_data['tip']

plt.scatter(X,Y)
plt.xlabel('total_bill')
plt.ylabel('tip')

plt.show()

# %%
plt.scatter(X, Y, s=np.array(Y)**2, c='green', alpha=0.8)
plt.title('Scatter Plot')

plt.xlabel('total_bill')
plt.ylabel('tip')

plt.show()

# %%
tips_data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
set(tips_data['smoker'])
# Out:
# {'No', 'Yes'}

# %%
tips_data.smoker.value_counts().plot(kind='bar', rot=0)
plt.show()

# %%
tips_data.smoker.value_counts()[1]+1
# Out:
# 94

# %%
tips_data.smoker.value_counts().plot(kind='bar', rot=0, color='green')

plt.text(x=-0.05, y=tips_data.smoker.value_counts()[0]+1, s=tips_data.smoker.value_counts()[0])
plt.text(x=0.98, y=tips_data.smoker.value_counts()[1]+1, s=tips_data.smoker.value_counts()[1])

plt.title('Bar Plot')
plt.xlabel('Smoker')
plt.ylabel('Count')

plt.show()

# %%
tips_data.shape
# Out:
# (244, 7)

# %%
tips_data.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
plt.pie(tips_data.day.value_counts(), autopct='%.1f%%', radius=1.2, labels=['Sat', 'Sun', 'Thur', 'Fri'])
plt.show()

# %%
plt.pie(tips_data.day.value_counts(), autopct='%.1f%%', radius=1.2, labels=['Sat', 'Sun', 'Thur', 'Fri'], explode=[0.2,0.2,0.3,0.5])

plt.show()

# %%
plt.pie(
    tips_data.day.value_counts(),
    autopct='%.1f%%',
    radius=1.2,
    labels=['Sat', 'Sun', 'Thur', 'Fri'],
    explode=[0,0,0,0]
    
)
circle = plt.Circle( (0,0), 0.9, color='white')
plot = plt.gcf()
plt.gca().add_artist(circle)

plt.show()

# %%
tips_data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.hist(tips_data['tip'], bins=5)

plt.title('Distribution of tip amount')
plt.xlabel('tip')
plt.ylabel('Frequency')

plt.show()

# %%
tips_data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.boxplot(tips_data['total_bill'])

plt.text(x = 1.1, y = tips_data['total_bill'].min(), s ='min')
plt.text(x = 1.1, y = tips_data.total_bill.quantile(0.25), s ='Q1')
plt.text(x = 1.1, y = tips_data['total_bill'].median(), s ='meadian (Q2)')
plt.text(x = 1.1, y = tips_data.total_bill.quantile(0.75), s ='Q3')
plt.text(x = 1.1, y = tips_data['total_bill'].max(), s ='max')

plt.title('Boxplot of Total Bill Amount')
plt.ylabel('Total Bill')

plt.show()

# %%
plt.boxplot(tips_data['total_bill'])

plt.text(x = 1.1, y = tips_data['total_bill'].min(), s ='min')
plt.text(x = 1.1, y = tips_data.total_bill.quantile(0.25), s ='Q1')
plt.text(x = 1.1, y = tips_data['total_bill'].median(), s ='meadian (Q2)')
plt.text(x = 1.1, y = tips_data.total_bill.quantile(0.75), s ='Q3')
plt.text(x = 1.1, y = tips_data['total_bill'].max(), s ='max')

plt.annotate('Outliers', xy=(0.97, 45), xytext=(0.7, 44), arrowprops=dict(facecolor='orange', arrowstyle='simple'))

plt.title('Boxplot of Total Bill Amount')
plt.ylabel('Total Bill')

plt.show()

# %%
sns.stripplot(y='tip', x='time', data=tips_data, hue="time", jitter=True)
plt.show()

# %%
sns.swarmplot(y='tip', x='time', data=tips_data, hue='day')
plt.show()

# %%
sns.violinplot(y='total_bill', x='day', data=tips_data)
plt.show()

# %%
sns.violinplot(y='total_bill', x='day', data=tips_data, hue='sex', split=True)
plt.show()

# %%
plt.figure(figsize = (8,8))

sns.pairplot(tips_data)

plt.show()
# Out:
# C:\Users\DELL\anaconda3\envs\AI\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.distplot(tips_data['total_bill'], hist_kws=None)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13588\450980439.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_data['total_bill'], hist_kws=None)

# %%
# # iterate the distplot() function over the time

# # list of time
time = ['Lunch', 'Dinner']

# # iterate through time
for i in time:
    subset = tips_data[tips_data['time'] == i]
    
# # Draw the density plot`
# # 'hist = False' will not plot a histogram
# # 'kde = True' plots density curve
    sns.distplot(subset['total_bill'], hist = False, kde = True,
                  kde_kws = {'shade':True},
                  label = i)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13588\1575288073.py:13: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(subset['total_bill'], hist = False, kde = True,
# C:\Users\DELL\anaconda3\envs\AI\lib\site-packages\seaborn\distributions.py:2511: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13588\1575288073.py:13: UserWarning:
#
# ...

# %%
sns.countplot(data=tips_data, x='day', hue='time')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use('fivethirtyeight')

# %%
data = sns.load_dataset('tips')

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill', y='tip', kind='scatter', data=data)
# Out:
# C:\Users\DELL\anaconda3\envs\AI\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', kind='scatter', data=data)
# Out:
# C:\Users\DELL\anaconda3\envs\AI\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', kind='scatter', style='sex', data=data)
# Out:
# C:\Users\DELL\anaconda3\envs\AI\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x='day', y='tip', kind='strip', data=data)
# Out:
# C:\Users\DELL\anaconda3\envs\AI\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x='day', y='tip', kind='swarm', hue='day', data=data)
# Out:
# C:\Users\DELL\anaconda3\envs\AI\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\DELL\anaconda3\envs\AI\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\anaconda3\envs\AI\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 6.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(data['tip'])
# Out:
# <Axes: >

# %%
sns.catplot(x='day', y='tip', kind='box', hue='sex', data=data)
# Out:
# C:\Users\DELL\anaconda3\envs\AI\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.violinplot(data['total_bill'])
# Out:
# <Axes: >

# %%
sns.catplot(x='day', y='tip', kind='violin', data=data)
# Out:
# C:\Users\DELL\anaconda3\envs\AI\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x='day', y='tip', kind='violin', hue='sex', split=True, data=data)
# Out:
# C:\Users\DELL\anaconda3\envs\AI\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
